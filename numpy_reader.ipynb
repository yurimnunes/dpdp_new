# %%
#numpy reader

import numpy as np
import os
import json

# %%
# read arquivo .npy
data = np.load('dados_solucao_validacao.npy', allow_pickle=True)
print(data.shape)
print(len(data))
# Out:
# (2000,)
# 2000

# %%
# print all values
import pandas as pd
# Configura o Pandas para exibir todas as linhas e colunas
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

aaa = pd.DataFrame(data[0])
aaa
# Out:
#        0
# 0      4
# 1     91
# 2     88
# 3     29
# 4     45
# 5     83
# 6     12
# 7     18
# 8     97
# 9      0
# 10    61
# 11    47
# 12    99
# 13    85
# 14    16
# 15    68
# 16     2
# 17    63
# 18    48
# 19     8
# 20    17
# 21    82
# 22     0
# 23    13
# 24    36
# 25    33
# 26    28
# 27     3
# 28    96
# 29    31
# 30     0
# 31     1
# 32    22
# 33    54
# 34    66
# 35    81
# 36     0
# 37    69
# 38    87
# 39    51
# 40    92
# 41     9
# 42    43
# 43    78
# 44    50
# 45    53
# 46    24
# 47     0
# 48    23
# 49    70
# 50    59
# 51    75
# 52    94
# 53    90
# 54    89
# 55    98
# 56    77
# 57    49
# 58    55
# 59     0
# 60    73
# 61    37
# 62    35
# 63    72
# 64    79
# 65    95
# 66    39
# 67    41
# 68    65
# 69     7
# 70    21
# 71    86
# 72    57
# 73    34
# 74     0
# 75    10
# 76    56
# 77    64
# 78    40
# 79    58
# 80    76
# 81    84
# 82    11
# 83    30
# 84    15
# 85     0
# 86    46
# 87     5
# 88    67
# 89    44
# 90    62
# 91    42
# 92     6
# 93    19
# 94    20
# 95     0
# 96   100
# 97    27
# 98    71
# 99    60
# 100   52
# 101    0
# 102   74
# 103   80
# 104   38
# 105   25
# 106   32
# 107   93
# 108   26
# 109   14

# %%
print(data[0])
# Out:
# [[0.61061373 0.49969313]
#  [0.30153259 0.66375993]
#  [0.11668164 0.87318889]
#  [0.16508386 0.2097758 ]
#  [0.3581691  0.53483565]
#  [0.88531253 0.5991898 ]
#  [0.54165829 0.84875932]
#  [0.24723551 0.24580873]
#  [0.45106348 0.46930074]
#  [0.69084414 0.8480583 ]]
