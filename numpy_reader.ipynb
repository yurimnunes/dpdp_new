# %%
#numpy reader

import numpy as np
import os
import json

# %%
# read arquivo .npy
data = np.load('tsp10_test.npy')
print(data.shape)
print(len(data))
# Out:
# (1000, 10, 2)
# 1000

# %%
data
# Out:
# array([[[0.61061373, 0.49969313],
#         [0.30153259, 0.66375993],
#         [0.11668164, 0.87318889],
#         ...,
#         [0.24723551, 0.24580873],
#         [0.45106348, 0.46930074],
#         [0.69084414, 0.8480583 ]],
#
#        [[0.01497577, 0.02358719],
#         [0.88617658, 0.78790812],
#         [0.00109061, 0.89858754],
#         ...,
#         [0.74106805, 0.68581158],
#         [0.64814704, 0.12117696],
#         [0.75605465, 0.61583556]],
#
#        [[0.83486462, 0.29833736],
#         [0.39035809, 0.44446035],
#         [0.39439873, 0.26191737],
#         ...,
#         [0.1812355 , 0.26697586],
#         [0.48758712, 0.63670124],
#         [0.86463315, 0.23716692]],
#
#        ...,
#
#        [[0.42963701, 0.36089411],
#         [0.02643991, 0.14259167],
#         [0.31479711, 0.91189083],
#         ...,
#         [0.22954591, 0.68706722],
#         [0.14928803, 0.94567577],
#         [0.34178781, 0.44351229]],
#
#        [[0.43280941, 0.93705148],
# ...

# %%
print(data[0])
# Out:
# [[0.61061373 0.49969313]
#  [0.30153259 0.66375993]
#  [0.11668164 0.87318889]
#  [0.16508386 0.2097758 ]
#  [0.3581691  0.53483565]
#  [0.88531253 0.5991898 ]
#  [0.54165829 0.84875932]
#  [0.24723551 0.24580873]
#  [0.45106348 0.46930074]
#  [0.69084414 0.8480583 ]]
